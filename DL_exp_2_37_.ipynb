# %% [markdown]
# **Experiment 1**

# %% [markdown]
# **Aim**: Create a deep learning model using mnist dataset

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

(X_train,y_train),(X_test,y_test) = keras.datasets.mnist.load_data()

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[2])

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
model = Sequential()
model.add(Flatten( input_shape=(28,28)))
model.add(Dense ( 128, activation = 'relu'))
model.add(Dense ( 32, activation = 'relu'))
model.add(Dense ( 11, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dense_2 (Dense)             (None, 11)                363
#
# =================================================================
# Total params: 104971 (410.04 KB)
# Trainable params: 104971 (410.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
history = model.fit(X_train,y_train,epochs=25,validation_split=0.2)
# Out:
# Epoch 1/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.2929 - accuracy: 0.9153 - val_loss: 0.1590 - val_accuracy: 0.9550
# Epoch 2/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1267 - accuracy: 0.9622 - val_loss: 0.1138 - val_accuracy: 0.9655
# Epoch 3/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0875 - accuracy: 0.9735 - val_loss: 0.1060 - val_accuracy: 0.9692
# Epoch 4/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0653 - accuracy: 0.9797 - val_loss: 0.0969 - val_accuracy: 0.9716
# Epoch 5/25
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0514 - accuracy: 0.9841 - val_loss: 0.0923 - val_accuracy: 0.9721
# Epoch 6/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0393 - accuracy: 0.9871 - val_loss: 0.1024 - val_accuracy: 0.9722
# Epoch 7/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0341 - accuracy: 0.9893 - val_loss: 0.1051 - val_accuracy: 0.9728
# Epoch 8/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.1079 - val_accuracy: 0.9714
# Epoch 9/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 0.1078 - val_accuracy: 0.9737
# Epoch 10/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 0.1055 - val_accuracy: 0.9745
# Epoch 11/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0975 - val_accuracy: 0.9772
# Epoch 12/25
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.1119 - val_accuracy: 0.9746
# Epoch 13/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.1156 - val_accuracy: 0.9747
# Epoch 14/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.1202 - val_accuracy: 0.9737
# Epoch 15/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.1251 - val_accuracy: 0.9762
# Epoch 16/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.1230 - val_accuracy: 0.9768
# Epoch 17/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.1271 - val_accuracy: 0.9764
# Epoch 18/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.1479 - val_accuracy: 0.9703
# Epoch 19/25
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.1375 - val_accuracy: 0.9747
# Epoch 20/25
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.1396 - val_accuracy: 0.9757
# Epoch 21/25
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.1294 - val_accuracy: 0.9768
# Epoch 22/25
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.1626 - val_accuracy: 0.9748
# Epoch 23/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.1575 - val_accuracy: 0.9753
# Epoch 24/25
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.1458 - val_accuracy: 0.9747
# Epoch 25/25
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.1417 - val_accuracy: 0.9776

# %%
y_prob = model.predict(X_test)
y_pred = y_prob.argmax(axis=1)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 313/313 [==============================] - 3s 7ms/step
# 0.9784

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
