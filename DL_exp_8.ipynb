# %% [markdown]
# Prerna Ladkani
#
# roll:37

# %% [markdown]
# Experiment 8

# %% [markdown]
# Aim: Denoising Auto Encoder

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models

# 1. Load and preprocess the data
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = np.expand_dims(x_train, axis=-1)  # (60000, 28, 28, 1)
x_test = np.expand_dims(x_test, axis=-1)    # (10000, 28, 28, 1)

# 2. Add noise to the data
def add_noise(x, noise_factor=0.5):
    x_noisy = x + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x.shape)
    x_noisy = np.clip(x_noisy, 0., 1.)
    return x_noisy

x_train_noisy = add_noise(x_train, noise_factor=0.5)
x_test_noisy = add_noise(x_test, noise_factor=0.5)

# Visualize some examples
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # Noisy
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title("Noisy")
    plt.axis('off')
plt.show()

# 3. Build the denoising autoencoder
input_shape = (28, 28, 1)
input_img = layers.Input(shape=input_shape)

# Encoder
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)  # 14x14x32
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)  # 7x7x32

# Decoder
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)  # 14x14x32
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)  # 28x28x32
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)  # 28x28x1

# Compile the model
autoencoder = models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.summary()

# 4. Train the model
history = autoencoder.fit(
    x_train_noisy, x_train,
    epochs=50,
    batch_size=128,
    shuffle=True,
    validation_data=(x_test_noisy, x_test)
)

# Plot training & validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 5. Evaluate the model
decoded_imgs = autoencoder.predict(x_test_noisy)

# Display the results
n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    # Noisy
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title("Noisy")
    plt.axis('off')

    # Denoised
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title("Denoised")
    plt.axis('off')

    # Original
    ax = plt.subplot(3, n, i + 1 + 2*n)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis('off')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 14, 14, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 28, 28, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 28, 28, 1)           │             289 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 28,353 (110.75 KB)
#  Trainable params: 28,353 (110.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.2599 - val_loss: 0.1168
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1155 - val_loss: 0.1079
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1082 - val_loss: 0.1043
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1048 - val_loss: 0.1023
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1027 - val_loss: 0.1006
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1014 - val_loss: 0.0999
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1003 - val_loss: 0.0988
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0994 - val_loss: 0.0979
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0987 - val_loss: 0.0976
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0981 - val_loss: 0.0971
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0975 - val_loss: 0.0967
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0974 - val_loss: 0.0965
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0969 - val_loss: 0.0961
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0967 - val_loss: 0.0960
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0964 - val_loss: 0.0957
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0961 - val_loss: 0.0955
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0959 - val_loss: 0.0961
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0960 - val_loss: 0.0955
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0956 - val_loss: 0.0951
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0954 - val_loss: 0.0949
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0954 - val_loss: 0.0950
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0952 - val_loss: 0.0949
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0952 - val_loss: 0.0950
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0951 - val_loss: 0.0946
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0948 - val_loss: 0.0945
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0947 - val_loss: 0.0944
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0947 - val_loss: 0.0944
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0946 - val_loss: 0.0946
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0944 - val_loss: 0.0942
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0944 - val_loss: 0.0943
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0944 - val_loss: 0.0941
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0942 - val_loss: 0.0942
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0942 - val_loss: 0.0941
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0942 - val_loss: 0.0941
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0941 - val_loss: 0.0941
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0941 - val_loss: 0.0940
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0940 - val_loss: 0.0940
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0939 - val_loss: 0.0939
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0940 - val_loss: 0.0938
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0938 - val_loss: 0.0939
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0936 - val_loss: 0.0940
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0934 - val_loss: 0.0936
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
